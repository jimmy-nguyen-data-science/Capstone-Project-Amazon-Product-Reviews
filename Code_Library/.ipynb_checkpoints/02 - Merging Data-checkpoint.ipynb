# %% [markdown]
# # Packages

# %%
import pandas as pd # pandas package
import numpy as np # numpy package
from pathlib import Path # path package

# %% [markdown]
# # Load Data sets

# %% [markdown]
# ### Amazon Fire TV Stick

# %%
# amazon fire tv stick data set
amz_df = pd.read_csv(Path(r"../Data/Raw Data/amz_firestick.csv"),  encoding='cp1252')

# product name
amz_df['product'] = 'Amazon Fire TV Stick'

# look at 5 random samples
amz_df.sample(5)
# Out:
#                             review_title  \
# 2260                       Fire Stick 4K
# 3674                         Works great
# 3419               Amazing stream, sound
# 2245  Better than most streaming devices
# 4642                   very good product
#
#                                             review_text         review_star  \
# 2260  This item is worth the money. I highly recomme...  5.0 out of 5 stars
# 3674                     Nothing to dislike works great  5.0 out of 5 stars
# 3419                             Everything works great  5.0 out of 5 stars
# 2245                                      Great product  5.0 out of 5 stars
# 4642                                     I'm a hobbyist  5.0 out of 5 stars
#
#                                                    date           author  \
# 2260       Reviewed in the United States on May 5, 2022         Kimberly
# 3674     Reviewed in the United States on March 1, 2022     matthew Ober
# 3419     Reviewed in the United States on June 13, 2022            hug-t
# 2245  Reviewed in the United States on December 21, ...      L. Chambers
# 4642     Reviewed in the United States on March 8, 2022  Abraham khourey
#
#       page               product
# 2260   227  Amazon Fire TV Stick
# 3674   368  Amazon Fire TV Stick
# 3419   342  Amazon Fire TV Stick
# 2245   225  Amazon Fire TV Stick
# 4642   465  Amazon Fire TV Stick

# %% [markdown]
# ### Google Chromecast

# %%
# google chromecast data set
google_df = pd.read_csv(Path(r"../Data/Raw Data/google_chromecast.csv"),  encoding='cp1252')

# add product name
google_df['product'] = 'Google ChromeCast'

# look at 5 random samples
google_df.sample(5)
# Out:
#               review_title                                        review_text  \
# 4049              Easy use    Such a great and easy product to use... love it
# 552        Easy to connect  I had no problem with it. All I had to do was ...
# 4013          Great device                        Had one before great device
# 2667  Great addition to TV  This is pretty solid. Grabbed this to use on a...
# 4865          Works great!  Bought this to stream HBO Max. Go figure, the ...
#
#              review_star                                               date  \
# 4049  5.0 out of 5 stars  Reviewed in the United States on November 17, ...
# 552   5.0 out of 5 stars   Reviewed in the United States on January 5, 2020
# 4013  4.0 out of 5 stars  Reviewed in the United States on January 14, 2021
# 2667  5.0 out of 5 stars    Reviewed in the United States on March 21, 2020
# 4865  3.0 out of 5 stars  Reviewed in the United States on December 21, ...
#
#                    author  page            product
# 4049       Paula Carvalho   405  Google ChromeCast
# 552                  Nora    56  Google ChromeCast
# 4013    charles alexander   402  Google ChromeCast
# 2667             Joe Todd   267  Google ChromeCast
# 4865  Gerald W Sapatka Jr   487  Google ChromeCast

# %% [markdown]
# ### Roku Remote

# %%
# roku remote data set
roku_df = pd.read_csv(Path(r"../Data/Raw Data/roku_remote.csv"),  encoding='cp1252')

# add product name
roku_df['product'] = 'Roku Remote'

# look at 5 random samples
roku_df.sample(5)
# Out:
#                                        review_title  \
# 1210                                 Super Pleased.
# 2981                                   Overall good
# 4692  Remote is not as nice as the previous version
# 2648                            Completely Amazing!
# 2927       easy to ook up and find movies ans shows
#
#                                             review_text         review_star  \
# 1210  Got this for my mom so she could stream Sling ...  5.0 out of 5 stars
# 2981  I had the original Roku and that worked fine b...  3.0 out of 5 stars
# 4692  There is no headphone jack on the remote like ...  3.0 out of 5 stars
# 2648  This product works amazing! Once connected to ...  5.0 out of 5 stars
# 2927  took our comcast out . love this product its l...  5.0 out of 5 stars
#
#                                                    date       author  page  \
# 1210  Reviewed in the United States on January 15, 2020        Andie   122
# 2981  Reviewed in the United States on December 18, ...         CCWT   299
# 4692      Reviewed in the United States on July 9, 2020  Brian James   470
# 2648  Reviewed in the United States on December 6, 2020     Ismaaeel   265
# 2927     Reviewed in the United States on July 23, 2019  doris hobbs   293
#
#           product
# 1210  Roku Remote
# 2981  Roku Remote
# 4692  Roku Remote
# 2648  Roku Remote
# 2927  Roku Remote

# %% [markdown]
# ### Apple TV

# %%
# apple tv data set
apple_df = pd.read_csv(Path(r"../Data/Raw Data/apple_tv.csv"),  encoding='cp1252')

# product name
apple_df['product'] = 'Apple TV'

# look at 5 random samples
apple_df.sample(5)
# Out:
#                                            review_title  \
# 1865                                        Easy to use
# 1114  Down with Cable /Satellite Prices and poor ser...
# 270                                       Great device!
# 455                                            electric
# 2443                          Remote INSANE sensitivity
#
#                                             review_text         review_star  \
# 1865                             I like it, easy to use  5.0 out of 5 stars
# 1114  Great picture and features, excellent value ov...  5.0 out of 5 stars
# 270   Very easy to install, and works great with my ...  5.0 out of 5 stars
# 455                                                  ok  5.0 out of 5 stars
# 2443  If there’s an earthquake anywhere on the same ...  3.0 out of 5 stars
#
#                                                    date           author  \
# 1865  Reviewed in the United States on February 11, ...  Patricia Matney
# 1114  Reviewed in the United States on February 19, ...               VT
# 270      Reviewed in the United States on April 7, 2020        slowgoing
# 455     Reviewed in the United States on April 29, 2019  Ryoji Taniguchi
# 2443   Reviewed in the United States on August 13, 2019            Brett
#
#       page   product
# 1865   187  Apple TV
# 1114   112  Apple TV
# 270     28  Apple TV
# 455     46  Apple TV
# 2443   245  Apple TV

# %% [markdown]
# # Merge all Data Sets

# %%
# concat all data sets into one
df = pd.concat([amz_df, google_df, roku_df, apple_df], axis=0)

# look at 5 random samples
df.sample(5)
# Out:
#                                   review_title  \
# 2826                      Good, but not great.
# 2650                                Five Stars
# 4698                       WiFi reaches garage
# 2763                                      FAST
# 4867  Like Roku Software More but Not Hardware
#
#                                             review_text         review_star  \
# 2826                               Good, but not great.  4.0 out of 5 stars
# 2650                                        works great  5.0 out of 5 stars
# 4698  Have many Roku and a Roku TV. The cheap ones d...  5.0 out of 5 stars
# 2763      Fast shipping!! Quality product!! Thank you!!  5.0 out of 5 stars
# 4867  The Fire TV software is getting better, but it...  5.0 out of 5 stars
#
#                                                    date             author  \
# 2826  Reviewed in the United States on December 31, ...  Billy Jean-Pierre
# 2650  Reviewed in the United States on February 15, ...    Thomas Ferguson
# 4698  Reviewed in the United States on January 20, 2020      Darren Spiker
# 2763     Reviewed in the United States on March 8, 2021     Sherri Butcher
# 4867  Reviewed in the United States on February 16, ...                 Me
#
#       page               product
# 2826   283     Google ChromeCast
# 2650   266           Roku Remote
# 4698   470           Roku Remote
# 2763   277           Roku Remote
# 4867   487  Amazon Fire TV Stick

# %%
# export to csv file
df.to_csv(Path(r"../Data/Merged Data/merged_data.csv"), index=False)
